# %%
# import the necessary packages
from imutils import paths
import numpy as np
import argparse
import imutils
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import requests
from io import BytesIO

# %%
images = []
for i in range(1,5):
    url = 'http://ec2-13-234-38-156.ap-south-1.compute.amazonaws.com/sih/public/app'+str(i)
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    images.append(img)
    print(url)
print(np.shape(images[0]))
# response = requests.get(url)
# img = Image.open(BytesIO(response.content))
# Out:
# http://ec2-13-234-38-156.ap-south-1.compute.amazonaws.com/sih/public/app1
# http://ec2-13-234-38-156.ap-south-1.compute.amazonaws.com/sih/public/app2
# http://ec2-13-234-38-156.ap-south-1.compute.amazonaws.com/sih/public/app3
# http://ec2-13-234-38-156.ap-south-1.compute.amazonaws.com/sih/public/app4
# (1080, 1920, 3)

# %%
# plt.imshow(images[0])
# n_images = []
# n_images = list(map(np.array,images))
# n_images = list(map(np.array,images))

# print(np.shape(n_images[0]))

# print("[INFO] stitching images...")
# stitcher = cv2.createStitcher() if imutils.is_cv3() else cv2.Stitcher_create()
# (status, stitched) = stitcher.stitch(n_images)

# %%
# plt.imshow(n_images[0])
# print(status)
# plt.imshow(stitched)

# %%
p1 = '/home/harshita/Downloads/1.jpeg'
im1 = cv2.imread(p1)
p2 = '/home/harshita/Downloads/2.jpeg'
im2 = cv2.imread(p2)
p3 = '/home/harshita/Downloads/3.jpeg'
im3 = cv2.imread(p3)

# %%
images = []
images.append(im1)
plt.imshow(im1)
images.append(im2)
plt.imshow(im2)

print(type(images))
# Out:
# <class 'list'>

# %%
plt.imshow(im1)

# %%
plt.imshow(im2)

# %%
plt.imshow(im3)

# %%
print("[INFO] stitching images...")
stitcher = cv2.createStitcher() if imutils.is_cv3() else cv2.Stitcher_create()
(status, stitched) = stitcher.stitch(images)
# Out:
# [INFO] stitching images...

# %%
print(status)
# Out:
# 0

# %%
# if the status is '0', then OpenCV successfully performed image
# stitching
if status == 0:
    plt.imshow(stitched)
   
 
# otherwise the stitching failed, likely due to not enough keypoints)
# being detected
else:
    print("[INFO] image stitching failed ({})".format(status))

# %%
print(type(stitched))
# Out:
# <class 'numpy.ndarray'>
